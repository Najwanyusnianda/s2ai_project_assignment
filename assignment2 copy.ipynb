# %% [markdown]
# # Classify Candidate Pairs of Acronyms and Expansions (Assignment 2)

# %% [markdown]
# ## 1. Import Library

# %%
import tarfile
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import tree
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import (
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 2. Prepare Dataset

# %% [markdown]
# ### 2.1 extract dataset

# %%
with tarfile.open("dataacro.tar.gz", "r:gz") as tar:
    tar.extractall("dataacro")

# %% [markdown]
# ### 2.2 Load dataset

# %% [markdown]
# #### 2.2.1 Define extract dataset function

# %%
def extract_feature(list_doc):
    X=[]
    y=[]
    for i in range(len(list_doc)):
        lines_feature=list_doc[i].split(" ")[-8:len(list_doc[i])]
        line_label=list_doc[i].split(" ")[-9]
        list_features=[float(line.strip().split(":")[1]) for line in lines_feature]
        list_label=int(line_label) 
        X.append(list_features)
        y.append(list_label)
    
    return X,y  

def extract_text(list_doc):
    X=[]
    y=[]
    for line in list_doc:
        text_feature=line.split(" ")[:-9]
        text_feature=" ".join(text_feature)
        line_label=line.split(" ")[-9]
        
        X.append(text_feature)
        y.append(line_label)
    
    return X

# %% [markdown]
# #### 2.2.2 Load and Preprocessing Data

# %%
with open("dataacro/trainingset.txt", "r") as file:
    training_lines = file.readlines()

with open("dataacro/testingset.txt", "r") as file:
    testing_lines = file.readlines()

  


X_train,y_train=extract_feature(training_lines)
X_test,y_test=extract_feature(testing_lines)   

X_train=np.array(X_train)
y_train=np.array(y_train)


X_test=np.array(X_test)
y_test=np.array(y_test)

#replace -1 with 0
y_train = np.where(y_train == -1, 0, y_train)
y_test = np.where(y_test == -1, 0, y_test)



X_train_text= extract_text(training_lines)
X_train_text=np.array(X_train_text)
X_train_text=X_train_text.reshape(-1,1)
X_test_text=extract_text(testing_lines)
X_test_text=np.array(X_test_text)
X_test_text=X_test_text.reshape(-1,1)
#check data length
print("Training data length: ", len(X_train))
print("Training data text length: ", len(X_train_text))
print("Training label length: ", len(y_train))
print("Testing data length: ", len(X_test))
print("Testing data text length: ", len(X_test_text))
print("Testing label length: ", len(y_test))
# Out:
# Training data length:  4000
# Training data text length:  4000
# Training label length:  4000
# Testing data length:  1099
# Testing data text length:  1099
# Testing label length:  1099

# %% [markdown]
# #### 2.2.3 Describe Data

# %%
col_name=['fitur '+str(i+1) for i in range(X_train.shape[1])]
df_train=pd.concat([pd.DataFrame(X_train,columns=col_name),pd.DataFrame(y_train,columns=['label'])],axis=1)

print(df_train.head().to_markdown())
# Out:
# |    |   fitur 1 |   fitur 2 |   fitur 3 |   fitur 4 |   fitur 5 |   fitur 6 |   fitur 7 |   fitur 8 |   label |
# |---:|----------:|----------:|----------:|----------:|----------:|----------:|----------:|----------:|--------:|
# |  0 |  0.918296 |  1        | -0.666667 |       0   |      1    |  0.5      |         0 | 0.39309   |       0 |
# |  1 |  1        |  0.5      | -2        |       0   |      0.75 |  0        |         0 | 0.0357143 |       0 |
# |  2 |  0.970951 |  1        | -1        |       0.5 |      1    |  0.333333 |         0 | 0.400612  |       0 |
# |  3 |  1        |  0.75     | -2        |       0   |      1    |  1        |         1 | 0.392857  |       0 |
# |  4 |  0.970951 |  0.666667 | -2.5      |       0   |      1    |  0        |         0 | 0.0196596 |       0 |

# %%
col_name=['fitur '+str(i+1) for i in range(X_train_text.shape[1])]
df_train_text=pd.concat([pd.DataFrame(X_train_text,columns=col_name),pd.DataFrame(y_train,columns=['label'])],axis=1)

print(df_train_text.head().to_markdown())
# Out:
# |    | fitur 1                          |   label |
# |---:|:---------------------------------|--------:|
# |  0 | BUMD=>Usaha Milik                |       0 |
# |  1 | TNI=>meminjam senjata dari oknum |       0 |
# |  2 | PKI=>Panitia Pengawas            |       0 |
# |  3 | MA=>putusan Mahkamah             |       0 |
# |  4 | TI=>com Mati body                |       0 |

# %% [markdown]
# ## 3. Build Model

# %%
eval_model_df_training=pd.DataFrame
eval_model_df=pd.DataFrame()

def input_model_result(df,y_true,y_pred,model_name):
    cm=confusion_matrix(y_true,y_pred)
    pre=precision_score(y_true,y_pred)
    rec=recall_score(y_true,y_pred)
    f1=f1_score(y_true,y_pred)
    
    data={
            'Model':model_name,
            "Confusion Matrix": [cm.tolist()],  # Convert to list to avoid issues
            "Precision": [pre],
            "Recall": [rec],
            "F1-Score": [f1]
        }
    if df.empty:
        df = pd.DataFrame([data])
    else:

        if model_name in df['Model'].values:
            print("Model already exists in the dataframe")
        else:
            df = pd.concat([df, pd.DataFrame([data])], ignore_index=True)
        
        print("added new result")
    return df

# %% [markdown]
# ### 3.1 SVM Classifier

# %%
svm = SVC(random_state=0)

x = [100.0,500.0]
y = [0.1,0.2,0.3]
z = [2,3S]    
parameters=[#{'C': x,'kernel': ['linear']},
            #{'C': x,'kernel': ['rbf'],'gamma': y} ,
            {'C': x,'kernel': ['poly'],'gamma': y,'degree': z}
           ]
grid=GridSearchCV(estimator = svm,
                        param_grid = parameters,
                        scoring='f1',
                        cv=10,
                        n_jobs=-1)
grid=grid.fit(X_train,y_train)
svm= grid.best_estimator_
best_params=grid.best_params_
best_score=grid.best_score_
print(f"The best parameters are {grid.best_params_} with" +
          f"a score of {grid.best_score_:.2f}")
# Out:
# The best parameters are {'C': 500.0, 'degree': 2, 'gamma': 0.2, 'kernel': 'poly'} witha score of 0.99

# %% [markdown]
# The best parameters are {'C': 500.0, 'degree': 2, 'gamma': 0.2, 'kernel': 'poly'} witha score of 0.99

# %%
y_pred= svm.predict(X_test)
eval_model_df = input_model_result(eval_model_df, y_test, y_pred,model_name='SVM-Polynomial')

# %%
eval_model_df
# Out:
#             Model         Confusion Matrix             Precision  \
# 0  SVM-Polynomial  [[[498, 2], [29, 570]]]  [0.9965034965034965]
#
#                  Recall              F1-Score
# 0  [0.9515859766277128]  [0.9735269000853971]

# %% [markdown]
# ### 3.2 KNN Classifier

# %%
## build model
knn = KNeighborsClassifier()
param_grid = {"n_neighbors": np.arange(2, 10)}
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid = GridSearchCV(knn, param_grid=param_grid,scoring="recall",cv=cv)
grid.fit(X_train, y_train)

print(f"The best parameters are {grid.best_params_} with" +
          f"a score of {grid.best_score_:.2f}")

knn = grid.best_estimator_

knn.fit(X_train, y_train)
# Out:
# The best parameters are {'n_neighbors': np.int64(9)} witha score of 0.86
# KNeighborsClassifier(n_neighbors=np.int64(9))

# %%
y_pred = knn.predict(X_train)
y_true = y_train
eval_model_df = input_model_result(eval_model_df, y_true, y_pred,model_name='knn')
report=classification_report(y_true,y_pred)
# Out:
# Model already exists in the dataframe
# added new result

# %% [markdown]
# ### 3.3 Naive Bayes Classifier

# %%
nb=GaussianNB()
nb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=nb.predict(X_train)
y_true=y_train

eval_model_df = input_model_result(eval_model_df, y_true, y_pred,model_name='Naive Bayes')
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.96      0.98      0.97      2000
#            1       0.98      0.96      0.97      2000
#
#     accuracy                           0.97      4000
#    macro avg       0.97      0.97      0.97      4000
# weighted avg       0.97      0.97      0.97      4000

# %% [markdown]
# ### 3.4 Decision Tree

# %%
dt=tree.DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(X_test)
y_true=y_test
print(classification_report(y_true,y_pred))

eval_model_df = input_model_result(eval_model_df, y_true, y_pred,model_name='Decision Tree')
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.90      0.99      0.95       500
#            1       0.99      0.91      0.95       599
#
#     accuracy                           0.95      1099
#    macro avg       0.95      0.95      0.95      1099
# weighted avg       0.95      0.95      0.95      1099
#
# added new result

# %% [markdown]
# ### 3.5 BERT

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from torch.utils.data import Dataset, DataLoader
import numpy as np
# Out:
# WARNING:tensorflow:From c:\Users\Najwan\miniconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        encoding = self.tokenizer(
            self.texts[idx], 
            truncation=True, 
            padding="max_length", 
            max_length=self.max_length, 
            return_tensors="pt"
        )
        return {
            "input_ids": encoding["input_ids"].squeeze(0),
            "attention_mask": encoding["attention_mask"].squeeze(0),
            "labels": torch.tensor(self.labels[idx], dtype=torch.long)
        }

# %%
# If X_train_text is a NumPy array
if (type(X_train_text) != list):
    X_train_text = X_train_text.tolist()  # Convert numpy array to list

 # Convert to list of strings

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

train_dataset = TextDataset(X_train_text, y_train, tokenizer)
test_dataset = TextDataset(X_test_text, y_test, tokenizer)

model = BertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=2)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# c:\Users\Najwan\miniconda3\Lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Najwan\.cache\huggingface\hub\models--bert-base-uncased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="./results",      
    num_train_epochs=3,          
    per_device_train_batch_size=8,  
    per_device_eval_batch_size=8,  
    warmup_steps=500,            
    weight_decay=0.01,           
    logging_dir="./logs",        
    logging_steps=10,
    evaluation_strategy="epoch",
    save_strategy="epoch"
)

bert = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=tokenizer
)

bert.train()
# Out:
# c:\Users\Najwan\miniconda3\Lib\site-packages\transformers\training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# C:\Users\Najwan\AppData\Local\Temp\ipykernel_18280\367871330.py:14: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   bert = Trainer(
#   0%|          | 0/1500 [00:00<?, ?it/s]
# {'loss': 0.7091, 'grad_norm': 5.335214138031006, 'learning_rate': 1.0000000000000002e-06, 'epoch': 0.02}
# {'loss': 0.6847, 'grad_norm': 6.239068031311035, 'learning_rate': 2.0000000000000003e-06, 'epoch': 0.04}
# {'loss': 0.6928, 'grad_norm': 5.495453357696533, 'learning_rate': 3e-06, 'epoch': 0.06}
# {'loss': 0.7023, 'grad_norm': 5.048561096191406, 'learning_rate': 4.000000000000001e-06, 'epoch': 0.08}
# {'loss': 0.689, 'grad_norm': 3.8396718502044678, 'learning_rate': 5e-06, 'epoch': 0.1}
# {'loss': 0.699, 'grad_norm': 2.9920356273651123, 'learning_rate': 6e-06, 'epoch': 0.12}
# {'loss': 0.6911, 'grad_norm': 4.778266429901123, 'learning_rate': 7.000000000000001e-06, 'epoch': 0.14}
# {'loss': 0.6872, 'grad_norm': 6.9926066398620605, 'learning_rate': 8.000000000000001e-06, 'epoch': 0.16}
# {'loss': 0.6481, 'grad_norm': 8.927323341369629, 'learning_rate': 9e-06, 'epoch': 0.18}
# {'loss': 0.6988, 'grad_norm': 3.699111223220825, 'learning_rate': 1e-05, 'epoch': 0.2}
# {'loss': 0.6444, 'grad_norm': 7.632023334503174, 'learning_rate': 1.1000000000000001e-05, 'epoch': 0.22}
# {'loss': 0.6295, 'grad_norm': 8.503348350524902, 'learning_rate': 1.2e-05, 'epoch': 0.24}
# {'loss': 0.6535, 'grad_norm': 8.012040138244629, 'learning_rate': 1.3000000000000001e-05, 'epoch': 0.26}
# {'loss': 0.625, 'grad_norm': 16.829998016357422, 'learning_rate': 1.4000000000000001e-05, 'epoch': 0.28}
# {'loss': 0.5631, 'grad_norm': 8.517179489135742, 'learning_rate': 1.5e-05, 'epoch': 0.3}
# {'loss': 0.5233, 'grad_norm': 9.376093864440918, 'learning_rate': 1.6000000000000003e-05, 'epoch': 0.32}
# {'loss': 0.516, 'grad_norm': 14.508196830749512, 'learning_rate': 1.7000000000000003e-05, 'epoch': 0.34}
# {'loss': 0.4279, 'grad_norm': 9.275232315063477, 'learning_rate': 1.8e-05, 'epoch': 0.36}
# {'loss': 0.3688, 'grad_norm': 7.040101051330566, 'learning_rate': 1.9e-05, 'epoch': 0.38}
# {'loss': 0.4437, 'grad_norm': 16.631622314453125, 'learning_rate': 2e-05, 'epoch': 0.4}
# {'loss': 0.4538, 'grad_norm': 8.903928756713867, 'learning_rate': 2.1e-05, 'epoch': 0.42}
# {'loss': 0.4031, 'grad_norm': 17.147010803222656, 'learning_rate': 2.2000000000000003e-05, 'epoch': 0.44}
# {'loss': 0.539, 'grad_norm': 25.271211624145508, 'learning_rate': 2.3000000000000003e-05, 'epoch': 0.46}
# {'loss': 0.4533, 'grad_norm': 10.677816390991211, 'learning_rate': 2.4e-05, 'epoch': 0.48}
# {'loss': 0.3617, 'grad_norm': 13.6839017868042, 'learning_rate': 2.5e-05, 'epoch': 0.5}
# {'loss': 0.5477, 'grad_norm': 9.932452201843262, 'learning_rate': 2.6000000000000002e-05, 'epoch': 0.52}
# {'loss': 0.329, 'grad_norm': 57.93280029296875, 'learning_rate': 2.7000000000000002e-05, 'epoch': 0.54}
# {'loss': 0.278, 'grad_norm': 61.52866744995117, 'learning_rate': 2.8000000000000003e-05, 'epoch': 0.56}
# {'loss': 0.4664, 'grad_norm': 30.129667282104492, 'learning_rate': 2.9e-05, 'epoch': 0.58}
# {'loss': 0.457, 'grad_norm': 11.188831329345703, 'learning_rate': 3e-05, 'epoch': 0.6}
# {'loss': 0.4327, 'grad_norm': 14.060111045837402, 'learning_rate': 3.1e-05, 'epoch': 0.62}
# {'loss': 0.3713, 'grad_norm': 5.040966033935547, 'learning_rate': 3.2000000000000005e-05, 'epoch': 0.64}
# {'loss': 0.2026, 'grad_norm': 22.073261260986328, 'learning_rate': 3.3e-05, 'epoch': 0.66}
# {'loss': 0.1597, 'grad_norm': 12.853904724121094, 'learning_rate': 3.4000000000000007e-05, 'epoch': 0.68}
# {'loss': 0.2887, 'grad_norm': 0.4126124680042267, 'learning_rate': 3.5e-05, 'epoch': 0.7}
# {'loss': 0.2923, 'grad_norm': 75.75891876220703, 'learning_rate': 3.6e-05, 'epoch': 0.72}
# {'loss': 0.405, 'grad_norm': 69.33697509765625, 'learning_rate': 3.7e-05, 'epoch': 0.74}
# {'loss': 0.2732, 'grad_norm': 3.927607536315918, 'learning_rate': 3.8e-05, 'epoch': 0.76}
# {'loss': 0.4803, 'grad_norm': 11.565645217895508, 'learning_rate': 3.9000000000000006e-05, 'epoch': 0.78}
# {'loss': 0.4412, 'grad_norm': 28.202896118164062, 'learning_rate': 4e-05, 'epoch': 0.8}
# {'loss': 0.4025, 'grad_norm': 13.065986633300781, 'learning_rate': 4.1e-05, 'epoch': 0.82}
# {'loss': 0.3354, 'grad_norm': 6.909380912780762, 'learning_rate': 4.2e-05, 'epoch': 0.84}
# {'loss': 0.2874, 'grad_norm': 19.475027084350586, 'learning_rate': 4.3e-05, 'epoch': 0.86}
# {'loss': 0.1367, 'grad_norm': 6.460432529449463, 'learning_rate': 4.4000000000000006e-05, 'epoch': 0.88}
# {'loss': 0.3193, 'grad_norm': 4.160853385925293, 'learning_rate': 4.5e-05, 'epoch': 0.9}
# {'loss': 0.3469, 'grad_norm': 12.081066131591797, 'learning_rate': 4.600000000000001e-05, 'epoch': 0.92}
# {'loss': 0.4929, 'grad_norm': 1.8761011362075806, 'learning_rate': 4.7e-05, 'epoch': 0.94}
# {'loss': 0.38, 'grad_norm': 44.33810806274414, 'learning_rate': 4.8e-05, 'epoch': 0.96}
# {'loss': 0.2497, 'grad_norm': 38.44578552246094, 'learning_rate': 4.9e-05, 'epoch': 0.98}
# {'loss': 0.3282, 'grad_norm': 10.645025253295898, 'learning_rate': 5e-05, 'epoch': 1.0}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 22
#       1 training_args = TrainingArguments(
#       2     output_dir="./results",
#       3     num_train_epochs=3,
#    (...)
#      11     save_strategy="epoch"
#      12 )
#      14 bert = Trainer(
#      15     model=model,
#      16     args=training_args,
#    (...)
#      19     tokenizer=tokenizer
#      20 )
# ---> 22 bert.train()
#
# File c:\Users\Najwan\miniconda3\Lib\site-packages\transformers\trainer.py:2123, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2121         hf_hub_utils.enable_progress_bars()
#    2122 else:
# -> 2123     return inner_training_loop(
#    2124         args=args,
#    2125         resume_from_checkpoint=resume_from_checkpoint,
#    2126         trial=trial,
#    2127         ignore_keys_for_eval=ignore_keys_for_eval,
#    2128     )
#
# File c:\Users\Najwan\miniconda3\Lib\site-packages\transformers\trainer.py:2573, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2570     self.control.should_training_stop = True
#    2572 self.control = self.callback_handler.on_epoch_end(args, self.state, self.control)
# -> 2573 self._maybe_log_save_evaluate(tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval)
#    2575 if DebugOption.TPU_METRICS_DEBUG in self.args.debug:
#    2576     if is_torch_xla_available():
#    2577         # tpu-comment: Logging debug metrics for PyTorch/XLA (compile, execute times, ops, etc.)
#
# File c:\Users\Najwan\miniconda3\Lib\site-packages\transformers\trainer.py:3004, in Trainer._maybe_log_save_evaluate(self, tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval)
#    3002 metrics = None
#    3003 if self.control.should_evaluate:
# -> 3004     metrics = self._evaluate(trial, ignore_keys_for_eval)
#    3006 if self.control.should_save:
#    3007     self._save_checkpoint(model, trial, metrics=metrics)
#
# File c:\Users\Najwan\miniconda3\Lib\site-packages\transformers\trainer.py:2958, in Trainer._evaluate(self, trial, ignore_keys_for_eval, skip_scheduler)
#    2957 def _evaluate(self, trial, ignore_keys_for_eval, skip_scheduler=False):
# -> 2958     metrics = self.evaluate(ignore_keys=ignore_keys_for_eval)
#    2959     self._report_to_hp_search(trial, self.state.global_step, metrics)
#    2961     # Run delayed LR scheduler now that metrics are populated
#
# File c:\Users\Najwan\miniconda3\Lib\site-packages\transformers\trainer.py:3975, in Trainer.evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    3972 start_time = time.time()
#    3974 eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
# -> 3975 output = eval_loop(
#    3976     eval_dataloader,
#    3977     description="Evaluation",
#    3978     # No point gathering the predictions if there are no metrics, otherwise we defer to
#    3979     # self.args.prediction_loss_only
#    3980     prediction_loss_only=True if self.compute_metrics is None else None,
#    3981     ignore_keys=ignore_keys,
#    3982     metric_key_prefix=metric_key_prefix,
#    3983 )
#    3985 total_batch_size = self.args.eval_batch_size * self.args.world_size
#    3986 if f"{metric_key_prefix}_jit_compilation_time" in output.metrics:
#
# File c:\Users\Najwan\miniconda3\Lib\site-packages\transformers\trainer.py:4159, in Trainer.evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    4156 observed_num_examples = 0
#    4158 # Main evaluation loop
# -> 4159 for step, inputs in enumerate(dataloader):
#    4160     # Update the observed num examples
#    4161     observed_batch_size = find_batch_size(inputs)
#    4162     if observed_batch_size is not None:
#
# File c:\Users\Najwan\miniconda3\Lib\site-packages\accelerate\data_loader.py:552, in DataLoaderShard.__iter__(self)
#     550 # We iterate one batch ahead to check when we are at the end
#     551 try:
# --> 552     current_batch = next(dataloader_iter)
#     553 except StopIteration:
#     554     yield
#
# File c:\Users\Najwan\miniconda3\Lib\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File c:\Users\Najwan\miniconda3\Lib\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\Najwan\miniconda3\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# Cell In[24], line 12, in TextDataset.__getitem__(self, idx)
#      11 def __getitem__(self, idx):
# ---> 12     encoding = self.tokenizer(
#      13         self.texts[idx],
#      14         truncation=True,
#      15         padding="max_length",
#      16         max_length=self.max_length,
#      17         return_tensors="pt"
#      18     )
#      19     return {
#      20         "input_ids": encoding["input_ids"].squeeze(0),
#      21         "attention_mask": encoding["attention_mask"].squeeze(0),
#      22         "labels": torch.tensor(self.labels[idx], dtype=torch.long)
#      23     }
#
# File c:\Users\Najwan\miniconda3\Lib\site-packages\transformers\tokenization_utils_base.py:3021, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3019     if not self._in_target_context_manager:
#    3020         self._switch_to_input_mode()
# -> 3021     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    3022 if text_target is not None:
#    3023     self._switch_to_target_mode()
#
# File c:\Users\Najwan\miniconda3\Lib\site-packages\transformers\tokenization_utils_base.py:3081, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3078         return False
#    3080 if not _is_valid_text_input(text):
# -> 3081     raise ValueError(
#    3082         "text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) "
#    3083         "or `List[List[str]]` (batch of pretokenized examples)."
#    3084     )
#    3086 if text_pair is not None and not _is_valid_text_input(text_pair):
#    3087     raise ValueError(
#    3088         "text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) "
#    3089         "or `List[List[str]]` (batch of pretokenized examples)."
#    3090     )
#
# ValueError: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).

# %%
# Get model predictions
predictions = bert.predict(test_dataset)
pred_labels = np.argmax(predictions.predictions, axis=1)

# Print classification report
print(classification_report(y_test, pred_labels, target_names=["0", "1"]))
