# %% [markdown]
# # Performance Comparison of Face Recognition Models (Assignment 3)

# %% [markdown]
# ## 1. Import Library

# %%
## import  libraries
import numpy as np
import pandas as pd
import requests
import os

# %% [markdown]
# ## 2. Download Dataset

# %%
## import metadata
facescrub_df = pd.read_csv('faceScrub/facescrub_actors.txt',delimiter='\t',header=None)

# Display the first few rows of the dataset
facescrub_df.head()
# Out:
#                0         1        2  \
# 0           name  image_id  face_id
# 1  Aaron Eckhart         1        1
# 2  Aaron Eckhart         2        2
# 3  Aaron Eckhart         3        3
# 4  Aaron Eckhart         4        4
#
#                                                    3                 4  \
# 0                                                url              bbox
# 1  http://upload.wikimedia.org/wikipedia/commons/...    53,177,418,542
# 2  http://movies.dosthana.com/sites/default/files...    80,102,260,282
# 3  http://upload.wikimedia.org/wikipedia/commons/...  203,802,975,1574
# 4  http://25.media.tumblr.com/nJ2vga5sae9o2ks4Flt...     62,90,231,259
#
#                                                    5
# 0                                             sha256
# 1  dec996994cf1eec33b53c203cff0e8f25638829fa2ad71...
# 2  f84d0c3b1b854a51e6bc031bc353e801834e81df795e85...
# 3  8548658ef00f2ac4c384fbfff9d3ae225b4b9e0c2aa45e...
# 4  658d83f35859d2f313ff660c1900427c21eae1c41e3035...

# %%
# Group by the first column (name) and count the occurrences
name_count_df = facescrub_df.groupby(facescrub_df.columns[0]).size().reset_index(name='count')

# Rename the columns for clarity
name_count_df.columns = ['name', 'count']
name_count_df.head()
# Display the new dataframe
#name_count_df=name_count_df.sort_values(by='count', ascending=False)

print(len(name_count_df))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Group by the first column (name) and count the occurrences
# ----> 2 name_count_df = facescrub_df.groupby(facescrub_df.columns[0]).size().reset_index(name='count')
#       4 # Rename the columns for clarity
#       5 name_count_df.columns = ['name', 'count']
#
# NameError: name 'facescrub_df' is not defined

# %%
def download_image(url, filename):
    
    try:
        response = requests.get(url, timeout=10, stream=True)
        #print(f"Status Code: {response.status_code}")
        response.raise_for_status()  # Raises an error for HTTP issues
        with open(filename, 'wb') as f:
            for chunk in response.iter_content(1024):
                f.write(chunk)
        #print("Download complete!")
        return 1
    except requests.exceptions.RequestException as e:
        #print(f"Error: {e}")
        #print("Download failed.")
        return 0
    

    

def get_image_sample(num_person,ntrain_person,ntest_person,facescrub_df):
    current_num_person = 0

    list_person = []

    while current_num_person<num_person:
        current_ntrain_person = 0
        current_ntest_person = 0
        ##generate angka random sebagai index dari dataset
        random_num = np.random.randint(0, facescrub_df.shape[0])
        ##ambil nama orang dari dataset
        
        current_person=facescrub_df.iloc[random_num,0]
        
        if current_person in list_person:
            continue
        else:
        ##buat dataset dengan data orang tersebut
            df_persons=facescrub_df[facescrub_df[0]==current_person]
            
            train_path = 'dataset/stagging/train/'+current_person
            test_path = 'dataset/stagging/test/'+current_person
            ##buat folder untuk orang tersebut
            if not os.path.exists(train_path):
                
                os.makedirs(train_path)
            if not os.path.exists(test_path):
                os.makedirs(test_path)

            len_train = print(f"num_image={df_persons.shape[0]}")=
            
            
            list_index_person=[]
            while current_ntrain_person<ntrain_person:
                    #get random index
                i = np.random.randint(0, df_persons.shape[0])
                if i in list_index_person:
                    continue
                else:
                    list_index_person.append(i)
                    ##ambil url gambar
                    url = df_persons.iloc[i,3]
                    ##download gambar
                    isdownload=download_image(url, train_path+'/'+current_person+'_'+str(current_ntrain_person+1)+'.jpg')
                    if isdownload==1:
                        current_ntrain_person+=1
                        if current_ntrain_person % 10 == 0:
                            print(f"train person image added for {current_person}: {current_ntrain_person}")
            while current_ntest_person<ntest_person:
                i = np.random.randint(0, df_persons.shape[0])
                if i in list_index_person:
                    continue
                else:
                    list_index_person.append(i)    
                     ##ambil url gambar
                    url = df_persons.iloc[i,3]
                    ##download gambar
                    isdownload=download_image(url, test_path+'/'+current_person+'_'+str(current_ntest_person+1)+'.jpg')
                    if isdownload==1:
                        current_ntest_person+=1
                        if current_ntest_person % 5 == 0:
                            print(f"test person image added fro {current_person}: {current_ntest_person}")
            list_person.append(current_person)
            current_num_person+=1
            print(f"=== [{current_num_person}/{num_person}] Person added: {current_person} ===")

# %%
##


##run function to get image sample
get_image_sample(num_person=200,ntrain_person=20,ntest_person=5,facescrub_df=facescrub_df)
# Out:
# num_image=269
# train person iamge added for Bill Hader: 10
# train person iamge added for Bill Hader: 20
# test person image added fro Bill Hader: 5
# Person 1/200 added: Bill Hader
# num_image=247
# train person iamge added for Alan Alda: 10
# train person iamge added for Alan Alda: 20
# test person image added fro Alan Alda: 5
# Person 2/200 added: Alan Alda
# num_image=252
# train person iamge added for Matthew Perry: 10
# train person iamge added for Matthew Perry: 20
# test person image added fro Matthew Perry: 5
# Person 3/200 added: Matthew Perry
# num_image=255
# train person iamge added for Taylor Lautner: 10
# train person iamge added for Taylor Lautner: 20
# test person image added fro Taylor Lautner: 5
# Person 4/200 added: Taylor Lautner
# num_image=189
# train person iamge added for David Cross: 10
# train person iamge added for David Cross: 20
# test person image added fro David Cross: 5
# Person 5/200 added: David Cross
# num_image=243
# train person iamge added for Jonathan Rhys Meyers: 10
# train person iamge added for Jonathan Rhys Meyers: 20
# test person image added fro Jonathan Rhys Meyers: 5
# Person 6/200 added: Jonathan Rhys Meyers
# num_image=150
# train person iamge added for Arnold Schwarzenegger: 10
# train person iamge added for Arnold Schwarzenegger: 20
# test person image added fro Arnold Schwarzenegger: 5
# Person 7/200 added: Arnold Schwarzenegger
# num_image=189
# train person iamge added for Antonio Banderas: 10
# train person iamge added for Antonio Banderas: 20
# test person image added fro Antonio Banderas: 5
# Person 8/200 added: Antonio Banderas
# num_image=204
# train person iamge added for Luke Wilson: 10
# train person iamge added for Luke Wilson: 20
# test person image added fro Luke Wilson: 5
# Person 9/200 added: Luke Wilson
# num_image=230
# train person iamge added for Gene Hackman: 10
# train person iamge added for Gene Hackman: 20
# test person image added fro Gene Hackman: 5
# Person 10/200 added: Gene Hackman
# num_image=219
# train person iamge added for Clive Owen: 10
# train person iamge added for Clive Owen: 20
# test person image added fro Clive Owen: 5
# Person 11/200 added: Clive Owen
# num_image=197
# train person iamge added for Justin Long: 10
# train person iamge added for Justin Long: 20
# test person image added fro Justin Long: 5
# Person 12/200 added: Justin Long
# num_image=178
# train person iamge added for Billy Boyd: 10
# train person iamge added for Billy Boyd: 20
# test person image added fro Billy Boyd: 5
# Person 13/200 added: Billy Boyd
# num_image=176
# train person iamge added for Hal Holbrook: 10
# train person iamge added for Hal Holbrook: 20
# test person image added fro Hal Holbrook: 5
# Person 14/200 added: Hal Holbrook
# num_image=176
# train person iamge added for Christopher Lloyd: 10
# train person iamge added for Christopher Lloyd: 20
# test person image added fro Christopher Lloyd: 5
# Person 15/200 added: Christopher Lloyd
# num_image=194
# train person iamge added for Christopher Reeve: 10
# train person iamge added for Christopher Reeve: 20
# test person image added fro Christopher Reeve: 5
# Person 16/200 added: Christopher Reeve
# num_image=155
# train person iamge added for Clint Eastwood: 10
# train person iamge added for Clint Eastwood: 20
# test person image added fro Clint Eastwood: 5
# Person 17/200 added: Clint Eastwood
# num_image=146
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\Najwa\miniconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File c:\Users\Najwa\miniconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File c:\Users\Najwa\miniconda3\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File c:\Users\Najwa\miniconda3\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     706 try:
# --> 707     return self._sock.recv_into(b)
#     708 except timeout:
#
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 5
#       1 ##
#       2
#       3
#       4 ##run function to get image sample
# ----> 5 get_image_sample(num_person=200,ntrain_person=20,ntest_person=5,facescrub_df=facescrub_df)
#
# Cell In[54], line 64, in get_image_sample(num_person, ntrain_person, ntest_person, facescrub_df)
#      62 url = df_persons.iloc[i,3]
#      63 ##download gambar
# ---> 64 isdownload=download_image(url, train_path+'/'+current_person+'_'+str(current_ntrain_person+1)+'.jpg')
#      65 if isdownload==1:
#      66     current_ntrain_person+=1
#
# Cell In[54], line 4, in download_image(url, filename)
#       1 def download_image(url, filename):
#       3     try:
# ----> 4         response = requests.get(url, timeout=10, stream=True)
#       5         #print(f"Status Code: {response.status_code}")
#       6         response.raise_for_status()  # Raises an error for HTTP issues
#
# File c:\Users\Najwa\miniconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Najwa\miniconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Najwa\miniconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Najwa\miniconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Najwa\miniconda3\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\Najwa\miniconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\Najwa\miniconda3\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\Najwa\miniconda3\Lib\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\Najwa\miniconda3\Lib\http\client.py:1444, in HTTPConnection.getresponse(self)
#    1442     return response
#    1443 except:
# -> 1444     response.close()
#    1445     raise
#
# File c:\Users\Najwa\miniconda3\Lib\http\client.py:430, in HTTPResponse.close(self)
#     427     self.fp = None
#     428     fp.close()
# --> 430 def close(self):
#     431     try:
#     432         super().close() # set "closed" flag
#
# KeyboardInterrupt:
